# %%
import numpy as np
import cv2

test_image = cv2.imread("/home/daria/Documents/traffic_sighs/10834.png")
image_gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
image_gray = cv2.GaussianBlur(image_gray, (3, 3), 0)
cv2.imwrite("gray.jpg", image_gray)
# Out:
# True

# %%
image_edged = cv2.Canny(image_gray, 10, 250)
cv2.imwrite("edged.jpg", image_edged)
# Out:
# True

# %%
kernel = cv2.getStructuringElement(cv2.MORPH_RECT, (7, 7))
image_closed = cv2.morphologyEx(image_edged, cv2.MORPH_CLOSE, kernel)
cv2.imwrite("closed.jpg", image_closed)
# Out:
# True

# %%
import keras
from keras.preprocessing import image
gray = image.load_img('gray.jpg',
    target_size = (512, 512))
gray
# Out:
# <PIL.Image.Image image mode=RGB size=512x512 at 0x7F2DFC70C0F0>

# %%
import keras
from keras.preprocessing import image
gray = image.load_img('edged.jpg',
    target_size = (512, 512))
gray
# Out:
# <PIL.Image.Image image mode=RGB size=512x512 at 0x7F2DFC70C2B0>

# %%
import keras
from keras.preprocessing import image
gray = image.load_img('closed.jpg',
    target_size = (512, 512))
gray
# Out:
# <PIL.Image.Image image mode=RGB size=512x512 at 0x7F2DFC6F8F28>
